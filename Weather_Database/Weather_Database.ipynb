# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
#from config import g_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
latitudes = np.random.uniform(low=-90.000, high=90.000, size=1500)
longitudes = np.random.uniform(low=-180.000, high=180.000, size=1500)
coords = zip(latitudes, longitudes)
coords

# %%
# Add the latitudes and longitudes to a list.
coords_list = list(coords)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coords_list:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    #print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 618

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 1 | lompoc
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | hobyo
# Processing Record 8 of Set 1 | codrington
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | ribeira do pombal
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | hualmay
# Processing Record 13 of Set 1 | tazovskiy
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | bereslavka
# Processing Record 16 of Set 1 | lock haven
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | biu
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | kouango
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | broome
# Processing Record 26 of Set 1 | ahipara
# Processing Record 27 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | nacozari
# Processing Record 31 of Set 1 | amberley
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | peachland
# Processing Record 34 of Set 1 | guerrero negro
# Processing Record 35 of Set 1 | labuhan
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | mainpuri
# Processing Record 38 of Set 1 | vao
# Processing Record 39 of Set 1 | san antonio
# Processing Record 40 of Set 1 | korla
# Processing Record 41 of Set 1 | egvekinot
# Processing Record 42 of Set 1 | yar-sale
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | victoria
# Processing Record 45 of Set 1 | rio grande
# Processing Record 46 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | rawson
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | dong hoi
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | airai
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | tiksi
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | qaqortoq
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | mercedes
# Processing Record 9 of Set 2 | waraseoni
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | fairbanks
# Processing Record 15 of Set 2 | iquique
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | acapulco
# Processing Record 18 of Set 2 | cremona
# Processing Record 19 of Set 2 | manokwari
# Processing Record 20 of Set 2 | darab
# Processing Record 21 of Set 2 | sandnessjoen
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 2 | aklavik
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | srednekolymsk
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | hay river
# Processing Record 29 of Set 2 | lebu
# Processing Record 30 of Set 2 | juneau
# Processing Record 31 of Set 2 | deputatskiy
# Processing Record 32 of Set 2 | baruun-urt
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | muroto
# Processing Record 35 of Set 2 | bairiki
# Processing Record 36 of Set 2 | ambon
# Processing Record 37 of Set 2 | ambovombe
# Processing Record 38 of Set 2 | hami
# Processing Record 39 of Set 2 | morden
# Processing Record 40 of Set 2 | antofagasta
# Processing Record 41 of Set 2 | severo-kurilsk
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | coquimbo
# Processing Record 44 of Set 2 | hambantota
# Processing Record 45 of Set 2 | dunedin
# Processing Record 46 of Set 2 | maltahohe
# Processing Record 47 of Set 2 | lima
# Processing Record 48 of Set 2 | djibo
# Processing Record 49 of Set 2 | esperance
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | honningsvag
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | greenlaw
# Processing Record 5 of Set 3 | san buenaventura
# Processing Record 6 of Set 3 | pedernales
# Processing Record 7 of Set 3 | faanui
# Processing Record 8 of Set 3 | moron
# Processing Record 9 of Set 3 | kachikau
# City not found. Skipping...
# Processing Record 10 of Set 3 | kloulklubed
# Processing Record 11 of Set 3 | vila velha
# Processing Record 12 of Set 3 | calabozo
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | vaini
# Processing Record 15 of Set 3 | antalya
# Processing Record 16 of Set 3 | guaiba
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | bougouni
# Processing Record 19 of Set 3 | san quintin
# Processing Record 20 of Set 3 | san pedro buenavista
# Processing Record 21 of Set 3 | hun
# Processing Record 22 of Set 3 | manoel urbano
# Processing Record 23 of Set 3 | touros
# Processing Record 24 of Set 3 | yaan
# Processing Record 25 of Set 3 | westport
# Processing Record 26 of Set 3 | namibe
# Processing Record 27 of Set 3 | inhambane
# Processing Record 28 of Set 3 | mecca
# Processing Record 29 of Set 3 | cardonal
# Processing Record 30 of Set 3 | namatanai
# Processing Record 31 of Set 3 | butaritari
# Processing Record 32 of Set 3 | albany
# Processing Record 33 of Set 3 | bengkalis
# City not found. Skipping...
# Processing Record 34 of Set 3 | lorengau
# Processing Record 35 of Set 3 | xai-xai
# Processing Record 36 of Set 3 | masuguru
# Processing Record 37 of Set 3 | comodoro rivadavia
# Processing Record 38 of Set 3 | rio gallegos
# Processing Record 39 of Set 3 | shingu
# Processing Record 40 of Set 3 | prachuap khiri khan
# Processing Record 41 of Set 3 | lupiro
# Processing Record 42 of Set 3 | hovd
# Processing Record 43 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 44 of Set 3 | mankera
# Processing Record 45 of Set 3 | sal rei
# Processing Record 46 of Set 3 | hilo
# Processing Record 47 of Set 3 | bethel
# Processing Record 48 of Set 3 | coahuayana
# Processing Record 49 of Set 3 | agadez
# Processing Record 50 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 4 | altea
# Processing Record 2 of Set 4 | puro
# Processing Record 3 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 4 | ngaoundere
# Processing Record 5 of Set 4 | samarai
# Processing Record 6 of Set 4 | humaita
# Processing Record 7 of Set 4 | torbay
# Processing Record 8 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 4 | los llanos de aridane
# Processing Record 10 of Set 4 | waverly
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | xinzhou
# Processing Record 13 of Set 4 | keti bandar
# Processing Record 14 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 4 | magadan
# Processing Record 16 of Set 4 | saint-georges
# Processing Record 17 of Set 4 | ayagoz
# Processing Record 18 of Set 4 | miri
# Processing Record 19 of Set 4 | viedma
# Processing Record 20 of Set 4 | mehamn
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | krasnoselkup
# Processing Record 23 of Set 4 | angoche
# Processing Record 24 of Set 4 | coihaique
# Processing Record 25 of Set 4 | barcelos
# Processing Record 26 of Set 4 | konya
# Processing Record 27 of Set 4 | calvinia
# Processing Record 28 of Set 4 | mogadishu
# Processing Record 29 of Set 4 | port lincoln
# Processing Record 30 of Set 4 | bubaque
# Processing Record 31 of Set 4 | evensk
# Processing Record 32 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 4 | takhatgarh
# Processing Record 34 of Set 4 | hobart
# Processing Record 35 of Set 4 | sola
# Processing Record 36 of Set 4 | mlonggo
# Processing Record 37 of Set 4 | san cristobal
# Processing Record 38 of Set 4 | dikson
# Processing Record 39 of Set 4 | anadyr
# Processing Record 40 of Set 4 | bilma
# Processing Record 41 of Set 4 | mankono
# Processing Record 42 of Set 4 | shahr-e babak
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | wattegama
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | birnin kebbi
# Processing Record 47 of Set 4 | beringovskiy
# Processing Record 48 of Set 4 | souillac
# Processing Record 49 of Set 4 | mahebourg
# Processing Record 50 of Set 4 | karlstad
# Processing Record 1 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 2 of Set 5 | north bend
# Processing Record 3 of Set 5 | dutse
# Processing Record 4 of Set 5 | leningradskiy
# Processing Record 5 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 5 | isangel
# Processing Record 7 of Set 5 | jacobabad
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 5 | vinh
# Processing Record 11 of Set 5 | kieta
# Processing Record 12 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 5 | peniche
# Processing Record 14 of Set 5 | conceicao do araguaia
# Processing Record 15 of Set 5 | raga
# Processing Record 16 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 17 of Set 5 | hofn
# Processing Record 18 of Set 5 | puerto madryn
# Processing Record 19 of Set 5 | constitucion
# Processing Record 20 of Set 5 | geraldton
# Processing Record 21 of Set 5 | cramlington
# Processing Record 22 of Set 5 | itarema
# Processing Record 23 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 5 | saga
# Processing Record 25 of Set 5 | okha
# Processing Record 26 of Set 5 | clarence town
# Processing Record 27 of Set 5 | bo phloi
# Processing Record 28 of Set 5 | adrar
# Processing Record 29 of Set 5 | avarua
# Processing Record 30 of Set 5 | kenai
# Processing Record 31 of Set 5 | hernani
# Processing Record 32 of Set 5 | mayo
# Processing Record 33 of Set 5 | ponta delgada
# Processing Record 34 of Set 5 | saint george
# Processing Record 35 of Set 5 | katete
# Processing Record 36 of Set 5 | banjar
# Processing Record 37 of Set 5 | karamken
# City not found. Skipping...
# Processing Record 38 of Set 5 | khatanga
# Processing Record 39 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 5 | oyem
# Processing Record 41 of Set 5 | port elizabeth
# Processing Record 42 of Set 5 | norrtalje
# Processing Record 43 of Set 5 | flin flon
# Processing Record 44 of Set 5 | cabo san lucas
# Processing Record 45 of Set 5 | talaya
# Processing Record 46 of Set 5 | kalabo
# Processing Record 47 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 5 | vostok
# Processing Record 49 of Set 5 | buchanan
# Processing Record 50 of Set 5 | nome
# Processing Record 1 of Set 6 | yefimovskiy
# City not found. Skipping...
# Processing Record 2 of Set 6 | avera
# Processing Record 3 of Set 6 | oussouye
# Processing Record 4 of Set 6 | mjolby
# Processing Record 5 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 6 | saint-francois
# Processing Record 7 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 6 | ostersund
# Processing Record 9 of Set 6 | haines junction
# Processing Record 10 of Set 6 | synya
# Processing Record 11 of Set 6 | maarianhamina
# Processing Record 12 of Set 6 | harigue
# City not found. Skipping...
# Processing Record 13 of Set 6 | shenjiamen
# Processing Record 14 of Set 6 | yuci
# Processing Record 15 of Set 6 | kalmunai
# Processing Record 16 of Set 6 | galesong
# Processing Record 17 of Set 6 | dondo
# Processing Record 18 of Set 6 | oga
# Processing Record 19 of Set 6 | grindavik
# Processing Record 20 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 6 | gat
# Processing Record 22 of Set 6 | fortuna
# Processing Record 23 of Set 6 | husavik
# Processing Record 24 of Set 6 | otavi
# Processing Record 25 of Set 6 | rumonge
# Processing Record 26 of Set 6 | klaksvik
# Processing Record 27 of Set 6 | umm kaddadah
# Processing Record 28 of Set 6 | methoni
# Processing Record 29 of Set 6 | vanimo
# Processing Record 30 of Set 6 | provideniya
# Processing Record 31 of Set 6 | emba
# Processing Record 32 of Set 6 | filingue
# Processing Record 33 of Set 6 | mumford
# Processing Record 34 of Set 6 | ariquemes
# Processing Record 35 of Set 6 | bathsheba
# Processing Record 36 of Set 6 | saint-philippe
# Processing Record 37 of Set 6 | new norfolk
# Processing Record 38 of Set 6 | pisco
# Processing Record 39 of Set 6 | fort nelson
# Processing Record 40 of Set 6 | saint-junien
# Processing Record 41 of Set 6 | poya
# Processing Record 42 of Set 6 | taltal
# Processing Record 43 of Set 6 | sao filipe
# Processing Record 44 of Set 6 | mokhsogollokh
# Processing Record 45 of Set 6 | vila franca do campo
# Processing Record 46 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 47 of Set 6 | taitung
# Processing Record 48 of Set 6 | aktash
# Processing Record 49 of Set 6 | arrecife
# Processing Record 50 of Set 6 | parras
# City not found. Skipping...
# Processing Record 1 of Set 7 | chokurdakh
# Processing Record 2 of Set 7 | jutai
# Processing Record 3 of Set 7 | aldan
# Processing Record 4 of Set 7 | banda aceh
# Processing Record 5 of Set 7 | qasigiannguit
# Processing Record 6 of Set 7 | tasiilaq
# Processing Record 7 of Set 7 | kakching
# Processing Record 8 of Set 7 | tabas
# Processing Record 9 of Set 7 | atikokan
# Processing Record 10 of Set 7 | pangnirtung
# Processing Record 11 of Set 7 | bengkulu
# Processing Record 12 of Set 7 | asfi
# Processing Record 13 of Set 7 | karatau
# Processing Record 14 of Set 7 | sinazongwe
# Processing Record 15 of Set 7 | aswan
# Processing Record 16 of Set 7 | cidreira
# Processing Record 17 of Set 7 | ciudad valles
# Processing Record 18 of Set 7 | maniitsoq
# Processing Record 19 of Set 7 | saint anthony
# Processing Record 20 of Set 7 | narsaq
# Processing Record 21 of Set 7 | ponta do sol
# Processing Record 22 of Set 7 | mount gambier
# Processing Record 23 of Set 7 | belyy yar
# Processing Record 24 of Set 7 | anloga
# Processing Record 25 of Set 7 | el badari
# City not found. Skipping...
# Processing Record 26 of Set 7 | mugla
# Processing Record 27 of Set 7 | megion
# Processing Record 28 of Set 7 | andros town
# Processing Record 29 of Set 7 | aloleng
# Processing Record 30 of Set 7 | college
# Processing Record 31 of Set 7 | merrill
# Processing Record 32 of Set 7 | malindi
# Processing Record 33 of Set 7 | bolshiye uki
# City not found. Skipping...
# Processing Record 34 of Set 7 | jumla
# Processing Record 35 of Set 7 | trairi
# Processing Record 36 of Set 7 | west plains
# Processing Record 37 of Set 7 | troitsko-pechorsk
# Processing Record 38 of Set 7 | brae
# Processing Record 39 of Set 7 | gushikawa
# Processing Record 40 of Set 7 | puerto del rosario
# Processing Record 41 of Set 7 | ushtobe
# Processing Record 42 of Set 7 | nova iguacu
# Processing Record 43 of Set 7 | oudtshoorn
# Processing Record 44 of Set 7 | nouadhibou
# Processing Record 45 of Set 7 | saint-pierre
# Processing Record 46 of Set 7 | salalah
# Processing Record 47 of Set 7 | cayenne
# Processing Record 48 of Set 7 | port-gentil
# Processing Record 49 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 7 | ippy
# Processing Record 1 of Set 8 | kui buri
# Processing Record 2 of Set 8 | sargur
# Processing Record 3 of Set 8 | tautira
# Processing Record 4 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 8 | zheshart
# Processing Record 7 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 8 | silleda
# Processing Record 9 of Set 8 | luderitz
# Processing Record 10 of Set 8 | tigzirt
# Processing Record 11 of Set 8 | tromso
# Processing Record 12 of Set 8 | valparaiso
# Processing Record 13 of Set 8 | andra
# Processing Record 14 of Set 8 | nakusp
# Processing Record 15 of Set 8 | poronaysk
# Processing Record 16 of Set 8 | ziarat
# Processing Record 17 of Set 8 | panguna
# Processing Record 18 of Set 8 | moyo
# Processing Record 19 of Set 8 | murom
# Processing Record 20 of Set 8 | pyu
# Processing Record 21 of Set 8 | santa isabel do rio negro
# Processing Record 22 of Set 8 | muros
# Processing Record 23 of Set 8 | kavieng
# Processing Record 24 of Set 8 | high level
# Processing Record 25 of Set 8 | paraopeba
# Processing Record 26 of Set 8 | talcahuano
# Processing Record 27 of Set 8 | ucluelet
# Processing Record 28 of Set 8 | xichang
# Processing Record 29 of Set 8 | kigoma
# Processing Record 30 of Set 8 | miles city
# Processing Record 31 of Set 8 | normandin
# Processing Record 32 of Set 8 | camacha
# Processing Record 33 of Set 8 | ketchikan
# Processing Record 34 of Set 8 | linxia
# Processing Record 35 of Set 8 | emerald
# Processing Record 36 of Set 8 | dingzhou
# Processing Record 37 of Set 8 | grand gaube
# Processing Record 38 of Set 8 | vardo
# Processing Record 39 of Set 8 | chapais
# Processing Record 40 of Set 8 | bilibino
# Processing Record 41 of Set 8 | lasa
# Processing Record 42 of Set 8 | visby
# Processing Record 43 of Set 8 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 44 of Set 8 | payo
# Processing Record 45 of Set 8 | sao sebastiao
# Processing Record 46 of Set 8 | tura
# Processing Record 47 of Set 8 | port-cartier
# Processing Record 48 of Set 8 | belaya gora
# Processing Record 49 of Set 8 | privolzhsk
# Processing Record 50 of Set 8 | naze
# Processing Record 1 of Set 9 | harindanga
# Processing Record 2 of Set 9 | regeneracao
# Processing Record 3 of Set 9 | patos
# Processing Record 4 of Set 9 | samana
# Processing Record 5 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 9 | richards bay
# Processing Record 7 of Set 9 | beloha
# Processing Record 8 of Set 9 | port hawkesbury
# Processing Record 9 of Set 9 | cuichapa
# Processing Record 10 of Set 9 | pitimbu
# Processing Record 11 of Set 9 | marystown
# Processing Record 12 of Set 9 | katsuura
# Processing Record 13 of Set 9 | shestakovo
# Processing Record 14 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 15 of Set 9 | yulara
# Processing Record 16 of Set 9 | benguela
# Processing Record 17 of Set 9 | fare
# Processing Record 18 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 9 | khandyga
# Processing Record 20 of Set 9 | bahia de caraquez
# Processing Record 21 of Set 9 | zemetchino
# Processing Record 22 of Set 9 | sechura
# Processing Record 23 of Set 9 | manzhouli
# Processing Record 24 of Set 9 | bodden town
# Processing Record 25 of Set 9 | kungurtug
# Processing Record 26 of Set 9 | buba
# Processing Record 27 of Set 9 | barinitas
# Processing Record 28 of Set 9 | pimenta bueno
# Processing Record 29 of Set 9 | chupa
# Processing Record 30 of Set 9 | weihai
# Processing Record 31 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 9 | carauari
# Processing Record 33 of Set 9 | zhezkazgan
# Processing Record 34 of Set 9 | laguna
# Processing Record 35 of Set 9 | koslan
# Processing Record 36 of Set 9 | bidor
# Processing Record 37 of Set 9 | harlingen
# Processing Record 38 of Set 9 | erzin
# Processing Record 39 of Set 9 | ajdabiya
# Processing Record 40 of Set 9 | pacific grove
# Processing Record 41 of Set 9 | winnipeg
# Processing Record 42 of Set 9 | andahuaylas
# Processing Record 43 of Set 9 | great falls
# Processing Record 44 of Set 9 | iqaluit
# Processing Record 45 of Set 9 | balykshi
# Processing Record 46 of Set 9 | kahului
# Processing Record 47 of Set 9 | panlaitan
# Processing Record 48 of Set 9 | ancud
# Processing Record 49 of Set 9 | nadvoitsy
# Processing Record 50 of Set 9 | san patricio
# Processing Record 1 of Set 10 | tabuk
# Processing Record 2 of Set 10 | orocue
# Processing Record 3 of Set 10 | dhidhdhoo
# Processing Record 4 of Set 10 | sorland
# Processing Record 5 of Set 10 | praia da vitoria
# Processing Record 6 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 7 of Set 10 | mahajanga
# Processing Record 8 of Set 10 | guarapari
# Processing Record 9 of Set 10 | alyangula
# Processing Record 10 of Set 10 | lingyuan
# Processing Record 11 of Set 10 | byron bay
# Processing Record 12 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 13 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 10 | jinchang
# Processing Record 15 of Set 10 | luganville
# Processing Record 16 of Set 10 | afgoye
# City not found. Skipping...
# Processing Record 17 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 10 | saint-augustin
# Processing Record 19 of Set 10 | larsnes
# Processing Record 20 of Set 10 | artyom
# Processing Record 21 of Set 10 | wakkanai
# Processing Record 22 of Set 10 | clyde river
# Processing Record 23 of Set 10 | dauphin
# Processing Record 24 of Set 10 | indianola
# Processing Record 25 of Set 10 | margate
# Processing Record 26 of Set 10 | gidole
# Processing Record 27 of Set 10 | yarega
# Processing Record 28 of Set 10 | kidal
# Processing Record 29 of Set 10 | poddorye
# Processing Record 30 of Set 10 | port blair
# Processing Record 31 of Set 10 | akureyri
# Processing Record 32 of Set 10 | dali
# Processing Record 33 of Set 10 | nioki
# Processing Record 34 of Set 10 | novoagansk
# Processing Record 35 of Set 10 | axim
# Processing Record 36 of Set 10 | kota kinabalu
# Processing Record 37 of Set 10 | karratha
# Processing Record 38 of Set 10 | sinop
# Processing Record 39 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 40 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 41 of Set 10 | sao joao da barra
# Processing Record 42 of Set 10 | omsukchan
# Processing Record 43 of Set 10 | quebrangulo
# Processing Record 44 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 10 | areia branca
# Processing Record 46 of Set 10 | cape coast
# Processing Record 47 of Set 10 | woodstock
# Processing Record 48 of Set 10 | goderich
# Processing Record 49 of Set 10 | tacuarembo
# Processing Record 50 of Set 10 | hudson bay
# Processing Record 1 of Set 11 | dingle
# Processing Record 2 of Set 11 | cockburn town
# Processing Record 3 of Set 11 | trincomalee
# Processing Record 4 of Set 11 | santa fe
# Processing Record 5 of Set 11 | campo largo
# Processing Record 6 of Set 11 | ayan
# Processing Record 7 of Set 11 | montreal
# Processing Record 8 of Set 11 | nador
# Processing Record 9 of Set 11 | mangai
# Processing Record 10 of Set 11 | luanda
# Processing Record 11 of Set 11 | stepnyak
# Processing Record 12 of Set 11 | padang
# Processing Record 13 of Set 11 | east london
# Processing Record 14 of Set 11 | alta floresta
# Processing Record 15 of Set 11 | raudeberg
# Processing Record 16 of Set 11 | grafton
# Processing Record 17 of Set 11 | dwarka
# Processing Record 18 of Set 11 | davila
# Processing Record 19 of Set 11 | koindu
# Processing Record 20 of Set 11 | hasaki
# Processing Record 21 of Set 11 | batagay
# Processing Record 22 of Set 11 | jishou
# Processing Record 23 of Set 11 | nogliki
# Processing Record 24 of Set 11 | pangai
# Processing Record 25 of Set 11 | villanueva
# Processing Record 26 of Set 11 | pochutla
# Processing Record 27 of Set 11 | vanavara
# Processing Record 28 of Set 11 | bima
# Processing Record 29 of Set 11 | komsomolskiy
# Processing Record 30 of Set 11 | yeppoon
# Processing Record 31 of Set 11 | yangshan
# Processing Record 32 of Set 11 | nikolayevsk-na-amure
# Processing Record 33 of Set 11 | requena
# Processing Record 34 of Set 11 | auki
# Processing Record 35 of Set 11 | pontes e lacerda
# Processing Record 36 of Set 11 | zhanaozen
# Processing Record 37 of Set 11 | dasoguz
# Processing Record 38 of Set 11 | gwadar
# Processing Record 39 of Set 11 | southbridge
# Processing Record 40 of Set 11 | nandu
# Processing Record 41 of Set 11 | belmopan
# Processing Record 42 of Set 11 | port augusta
# Processing Record 43 of Set 11 | palauig
# Processing Record 44 of Set 11 | beruni
# City not found. Skipping...
# Processing Record 45 of Set 11 | te anau
# Processing Record 46 of Set 11 | suez
# Processing Record 47 of Set 11 | khandbari
# Processing Record 48 of Set 11 | kabanjahe
# Processing Record 49 of Set 11 | betong
# Processing Record 50 of Set 11 | aulnoye-aymeries
# Processing Record 1 of Set 12 | sidi qasim
# City not found. Skipping...
# Processing Record 2 of Set 12 | bani walid
# Processing Record 3 of Set 12 | hurricane
# Processing Record 4 of Set 12 | palmer
# Processing Record 5 of Set 12 | sao jose da coroa grande
# Processing Record 6 of Set 12 | manta
# Processing Record 7 of Set 12 | tandil
# Processing Record 8 of Set 12 | isabela
# Processing Record 9 of Set 12 | peterhead
# Processing Record 10 of Set 12 | riyadh
# Processing Record 11 of Set 12 | marawi
# Processing Record 12 of Set 12 | berlevag
# Processing Record 13 of Set 12 | ambilobe
# Processing Record 14 of Set 12 | wanning
# Processing Record 15 of Set 12 | murgab
# Processing Record 16 of Set 12 | beira
# Processing Record 17 of Set 12 | merauke
# Processing Record 18 of Set 12 | qafsah
# City not found. Skipping...
# Processing Record 19 of Set 12 | priargunsk
# Processing Record 20 of Set 12 | tuatapere
# Processing Record 21 of Set 12 | saquarema
# Processing Record 22 of Set 12 | waddan
# Processing Record 23 of Set 12 | tartagal
# Processing Record 24 of Set 12 | fukue
# Processing Record 25 of Set 12 | dalby
# Processing Record 26 of Set 12 | balkhash
# Processing Record 27 of Set 12 | ulladulla
# Processing Record 28 of Set 12 | port hardy
# Processing Record 29 of Set 12 | havelock
# Processing Record 30 of Set 12 | marolambo
# Processing Record 31 of Set 12 | liberal
# Processing Record 32 of Set 12 | la ligua
# Processing Record 33 of Set 12 | podporozhye
# Processing Record 34 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 12 | nanortalik
# Processing Record 36 of Set 12 | paamiut
# Processing Record 37 of Set 12 | pietarsaari
# Processing Record 38 of Set 12 | gamba
# Processing Record 39 of Set 12 | cairns
# Processing Record 40 of Set 12 | igarape-miri
# City not found. Skipping...
# Processing Record 41 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 12 | wyndham
# Processing Record 43 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 44 of Set 12 | khalilabad
# Processing Record 45 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 12 | kavaratti
# Processing Record 47 of Set 12 | puerto rico
# Processing Record 48 of Set 12 | saurimo
# Processing Record 49 of Set 12 | vesyegonsk
# Processing Record 50 of Set 12 | puerto leguizamo
# Processing Record 1 of Set 13 | iracoubo
# Processing Record 2 of Set 13 | gold coast
# Processing Record 3 of Set 13 | ixtapa
# Processing Record 4 of Set 13 | aripuana
# Processing Record 5 of Set 13 | luleburgaz
# Processing Record 6 of Set 13 | concordia
# Processing Record 7 of Set 13 | camocim
# Processing Record 8 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 13 | zomin
# Processing Record 10 of Set 13 | lagoa
# Processing Record 11 of Set 13 | levelland
# Processing Record 12 of Set 13 | marsa matruh
# Processing Record 13 of Set 13 | lagdo
# Processing Record 14 of Set 13 | la palma
# Processing Record 15 of Set 13 | nishihara
# Processing Record 16 of Set 13 | muravlenko
# Processing Record 17 of Set 13 | grakhovo
# Processing Record 18 of Set 13 | yuksekova
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 561

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                     Lompoc      US  34.6391 -120.4579     65.57        64
# 1                  Jamestown      US  42.0970  -79.2353     41.09        61
# 2                Tuktoyaktuk      CA  69.4541 -133.0374    -14.80        76
# 3  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483      5.59        72
# 4                 Nikolskoye      RU  59.7035   30.7861     30.09        99
# 5                      Hobyo      SO   5.3505   48.5268     78.31        82
# 6                 Codrington      AU -38.2667  141.9667     66.18        77
# 7                      Bluff      NZ -46.6000  168.3333     52.81        68
# 8          Ribeira Do Pombal      BR -10.8344  -38.5358     81.46        63
# 9               Kruisfontein      ZA -34.0033   24.7314     58.89        67
#
#    Cloudiness  Wind Speed Current Description
# 0           1        6.91           clear sky
# 1           1        1.99           clear sky
# 2          90        9.22          light snow
# 3          75       11.18   light shower snow
# 4          93        3.27     overcast clouds
# 5          98       19.44     overcast clouds
# 6          38       16.17    scattered clouds
# 7          72       25.34       broken clouds
# 8          64       11.12       broken clouds
# 9           1       13.51           clear sky

# %%
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df.head(10)
# Out:
#                         City Country     Lat      Lng  Max Temp  Humidity  \
# 0                     Lompoc      US   34.64  -120.46     65.57        64
# 1                  Jamestown      US   42.10   -79.24     41.09        61
# 2                Tuktoyaktuk      CA   69.45  -133.04    -14.80        76
# 3  Petropavlovsk-Kamchatskiy      RU   53.05   158.65      5.59        72
# 4                 Nikolskoye      RU   59.70    30.79     30.09        99
# 5                      Hobyo      SO    5.35    48.53     78.31        82
# 6                 Codrington      AU  -38.27   141.97     66.18        77
# 7                      Bluff      NZ  -46.60   168.33     52.81        68
# 8          Ribeira Do Pombal      BR  -10.83   -38.54     81.46        63
# 9               Kruisfontein      ZA  -34.00    24.73     58.89        67
#
#    Cloudiness  Wind Speed Current Description
# 0           1        6.91           clear sky
# 1           1        1.99           clear sky
# 2          90        9.22          light snow
# 3          75       11.18   light shower snow
# 4          93        3.27     overcast clouds
# 5          98       19.44     overcast clouds
# 6          38       16.17    scattered clouds
# 7          72       25.34       broken clouds
# 8          64       11.12       broken clouds
# 9           1       13.51           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
